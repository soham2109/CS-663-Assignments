# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib as mpl
from numpy import zeros,zeros_like,array
from mpl_toolkits.axes_grid1 import ImageGrid
# Out:
# In /home/akshay/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/akshay/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/akshay/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/akshay/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/akshay/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/akshay/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/akshay/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/akshay/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
input_file = "../data/chestXray.png"
input_image =255*mpimg.imread(input_file,format="png")

# %%
fig,axes = plt.subplots(1,1, constrained_layout=True, gridspec_kw={'width_ratios':[1]})
im=axes.imshow(input_image,cmap="gray")
axes.axis("on")
# im = axes[1].imshow(new_image,cmap="gray")
# axes[1].axis("on")
# im = axes[2].imshow(masked_image,cmap="gray")
# axes[2].axis("on")

plt.show()

# %%
hist, bins = np.histogram(input_image, bins = [i for i in range(0,np.max(input_image),20)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-e78c96ae1210> in <module>
# ----> 1 hist, bins = np.histogram(input_image, bins = [i for i in range(0,np.max(input_image),20)])
#
# TypeError: 'numpy.float32' object cannot be interpreted as an integer

# %%
def contrast_stretching(input_file,tune=97):
    input_image = mpimg.imread(input_file,format="png")
    if (len(input_image.shape)==2):
        input_image=255*input_image
        minimum = [np.min(input_image)]
        maximum=[np.max(input_image)]

    else:
        modified_image=(input_image[:,:,0] + input_image[:,:,1] + input_image[:,:,2] )/3

        minimum=np.minimum(modified_image)
        maximum=np.maximum(modified_image)
        print(minimum)
        print(maximum)
    
    new_image=np.zeros_like(input_image)
    for i in range (input_image.shape[0]):
        for j in range(input_image.shape[1]):
            for k in range(len(minimum)):
                input_pixel = input_image[i][j][k] if len(minimum)>2 else input_image[i][j]
                print(minimum[k])
                x= input_pixel - minimum[k]
                print(x)
                break
                if x>=0:
                    out = (x)/(maximum[k]-minimum[k])
                else:
                    out=0
                if (len(minimum)>2):
                    new_image[i][j][k]=out
                else:
                    new_image[i][j]=out
            break
        break
    
    fig,axes = plt.subplots(1,2, constrained_layout=True, gridspec_kw={'width_ratios':[1,1]})
    axes[0].imshow(input_image,cmap="gray")
    axes[0].axis("on")
    axes[1].imshow(new_image,cmap="gray")
    axes[1].axis("on")
    plt.show()

# %%
#input_file = "../data/chestXray.png"
#contrast_stretching(input_file)
# input_file = "../data/barbara.png"
# contrast_stretching(input_file,tune=70)
# input_file = "../data/statue.png"
# contrast_stretching(input_file,tune=0)
input_file = "../data/church.png"
contrast_stretching(input_file,tune=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-313-53ee8f94e682> in <module>
#       6 # contrast_stretching(input_file,tune=0)
#       7 input_file = "../data/church.png"
# ----> 8 contrast_stretching(input_file,tune=0)
#
# <ipython-input-312-bcde7e20eb6b> in contrast_stretching(input_file, tune)
#       9         modified_image=(input_image[:,:,0] + input_image[:,:,1] + input_image[:,:,2] )/3
#      10
# ---> 11         minimum=np.minimum(modified_image)
#      12         maximum=np.maximum(modified_image)
#      13         print(minimum)
#
# ValueError: invalid number of arguments

# %%
#hist = np.histogram(input_image)  
plt.hist(input_image,bins=[0,50,100,150,200,255])
plt.show()

# %%
plt.hist(new_image,bins=[0,50,100,150,200,255])
plt.show()
